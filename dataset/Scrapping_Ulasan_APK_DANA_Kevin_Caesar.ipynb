# %% [markdown]
# Nama : Kevin Caesar
#
# email dicoding : kevin.caesar-2020@ftmm.unair.ac.id
#
# user/id dicoding :kevin_caesar_LVy6

# %% [markdown]
# # A. library

# %%
# !pip install google-play-scraper

# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort

# %% [markdown]
# # B. Scrapping Data

# %%
# Mengimpor pustaka google_play_scraper untuk mengakses ulasan dan informasi aplikasi dari Google Play Store.
from google_play_scraper import app, reviews, Sort

# Mengambil 30000 ulasan dari aplikasi dengan ID 'id.dana' di Google Play Store.
scrapreview,continuation_token = reviews(
    'id.dana',                         # ID aplikasi dana
    lang='id',                         # Bahasa ulasan (default: 'en')
    country='id',                      # Negara (default: 'us')
    sort=Sort.MOST_RELEVANT,           # Urutan ulasan (default: Sort.MOST_RELEVANT)
    count=30000                        # Jumlah maksimum 30000 ulasan yang ingin diambil
)

# %%
# Menyimpan ulasan dalam file CSV
import csv

with open('ulasan_dana.csv', mode='w', newline='', encoding='utf-8') as file:
    writer = csv.writer(file)
    writer.writerow(['Review'])  # Menulis header kolom
    for review in scrapreview:
        writer.writerow([review['content']])  # Menulis konten ulasan ke dalam file CSV

# %%
import pandas as pd  # Pandas untuk manipulasi dan analisis data
pd.options.mode.chained_assignment = None  # Menonaktifkan peringatan chaining

app_review_df = pd.DataFrame(scrapreview)
app_review_df.shape
app_review_df.head()
app_review_df.to_csv('ulasan_dana.csv', index=False)


# Membuat DataFrame dari hasil scrapreview
app_review_df = pd.DataFrame(scrapreview)

# Menghitung jumlah baris dan kolom dalam DataFrame
jumlah_ulasan, jumlah_kolom = app_review_df.shape

# %%
# Menampilkan lima baris pertama dari DataFrame app_reviews_df
app_review_df.head()
# Out:
#                                reviewId         userName  \
# 0  faf87733-fa9f-4518-8da5-201e72345807  Pengguna Google
# 1  a0aed441-6df4-4f77-ab91-5533f5a766cb  Pengguna Google
# 2  e8509faa-1481-4ef3-9048-1ae2886e347b  Pengguna Google
# 3  026d40a1-c4d9-4d46-bbe5-71d953823456  Pengguna Google
# 4  64af6dcb-eec3-4d69-9cde-0163ffce5f20  Pengguna Google
#
#                                            userImage  \
# 0  https://play-lh.googleusercontent.com/EGemoI2N...
# 1  https://play-lh.googleusercontent.com/EGemoI2N...
# 2  https://play-lh.googleusercontent.com/EGemoI2N...
# 3  https://play-lh.googleusercontent.com/EGemoI2N...
# 4  https://play-lh.googleusercontent.com/EGemoI2N...
#
#                                              content  score  thumbsUpCount  \
# 0  Ini gimana sih biasanya gak pakai verifikasi w...      2            138
# 1  masih ribet, kurang simpel proses premiumnya. ...      1             21
# ...

# %%
app_review_df.shape
# Out:
# (30000, 11)

# %%
# Menampilkan informasi tentang DataFrame app_reviews_df
app_review_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 30000 entries, 0 to 29999
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   reviewId              30000 non-null  object
#  1   userName              30000 non-null  object
#  2   userImage             30000 non-null  object
#  3   content               30000 non-null  object
#  4   score                 30000 non-null  int64
#  5   thumbsUpCount         30000 non-null  int64
#  6   reviewCreatedVersion  28036 non-null  object
#  7   at                    30000 non-null  datetime64[ns]
#  8   replyContent          29688 non-null  object
#  9   repliedAt             29688 non-null  datetime64[ns]
#  10  appVersion            28036 non-null  object
# dtypes: datetime64[ns](2), int64(2), object(7)
# memory usage: 2.5+ MB

# %%
# Membuat DataFrame baru (clean_df) dengan menghapus baris yang memiliki nilai yang hilang (NaN) dari app_reviews_df
clean_df = app_review_df.dropna()

#menghapus kolom yang tidak dibutuhkan
clean_df =clean_df.drop(['reviewId', 'userName', 'userImage','thumbsUpCount', 'reviewCreatedVersion', 'replyContent',
       'repliedAt', 'appVersion','at'], axis=1)
clean_df
# Out:
#                                                  content  score
# 0      Ini gimana sih biasanya gak pakai verifikasi w...      2
# 1      masih ribet, kurang simpel proses premiumnya. ...      1
# 2      Tidak mudah membuat laporan keluhan.. ketika m...      2
# 3      menurut saya apknya kurang dalam hal transaksi...      1
# 4      Kenapa saldo saya tbtb terpotong otomatis pada...      1
# ...                                                  ...    ...
# 29993  Mohon Segera Diperbaiki Saya sudah sangat seri...      1
# 29994  Ini dana ada kendala apa sih? Kenapa saldo ku ...      2
# 29996  Bagaimana platform yg katanya aman bs d bobol ...      1
# 29997  Hati dengan pengguna dana, saldo saya setiap t...      1
# 29998  Aku sering bget isi pulsa tpi ga masuk2, padah...      1
#
# [27757 rows x 2 columns]

# %%
# Menghapus indeks
df_pemodelan = clean_df.reset_index(drop=True)

# %%
# mendownload hasil ulasan dalam file csv
from google.colab import files
df_pemodelan.to_csv('ulasan_pemodelan.csv',index=False)
files.download('ulasan_dana.csv') # hasil setelah scraping
files.download('ulasan_pemodelan.csv') #hasil setelah dipreprocessing dihilangkan NaN dan untuk pemodelan
print("file ulasan sudah berhasil didownload!")
# Out:
# file ulasan sudah berhasil didownload!

# %% [markdown]
# penjelasan:
#
# data ulasan yang tadinya berjumlah 30.000 ulasan menjadi 27.757 ulasan menghapus baris memiliki nilai NaN. Dengan demikian, 27.757 ulasan digunakan untuk menganalisis analisis sentimen

# %% [markdown]
# # c. requirement txt

# %%
# !pip install pipreqs
from google.colab import drive
drive.mount('/content/drive')
# Out:
# ...
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# !pipreqs "/content/drive/MyDrive/Colab Notebooks/NLP_Scrapping_dicoding" --scan-notebooks
# Out:
# WARNING: Import named "google_play_scraper" not found locally. Trying to resolve it at the PyPI server.
# WARNING: Import named "google_play_scraper" was resolved to "google-play-scraper:1.2.7" package (https://pypi.org/project/google-play-scraper/).
# Please, verify manually the final list of requirements.txt to avoid possible dependency confusions.
# INFO: Successfully saved requirements file in /content/drive/MyDrive/Colab Notebooks/NLP_Scrapping_dicoding/requirements.txt
